# %%
# !pip install pesq
# !pip install pystoi
# Out:
# Collecting pesq
#   Downloading pesq-0.0.3.tar.gz (35 kB)
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.3-cp37-cp37m-linux_x86_64.whl size=209966 sha256=ab885c0bade0b9eb7dba0153161427039f79042ac7c4195375ef0999dbe7795f
#   Stored in directory: /root/.cache/pip/wheels/4f/67/5b/aa7cf31fe0c7199e35c604bb7bc91c629a13726bf221fedba0
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.3
# Collecting pystoi
#   Downloading pystoi-0.3.3.tar.gz (7.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pystoi) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pystoi) (1.4.1)
# Building wheels for collected packages: pystoi
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7793 sha256=40533e291f07f32fdf30884a134a31892f60541e9f37c93f55ff672190d75496
#   Stored in directory: /root/.cache/pip/wheels/46/4a/ad/3ab460193ed0535430b4b1575f255aa6bae69df17453628e86
# Successfully built pystoi
# Installing collected packages: pystoi
# Successfully installed pystoi-0.3.3

# %%
cd /content/drive/Othercomputers/Desktop/Workspace/Python/Artificial_Intelligence_Project/Speechless
# Out:
# /content/drive/Othercomputers/Desktop/Workspace/Python/Artificial_Intelligence_Project/Speechless

# %% [markdown]
# # Google Colab 사양

# %%
import platform
platform.platform()
# Out:
# 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.168
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.33
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.168
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.33
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302924 kB
# MemFree:        10251932 kB
# MemAvailable:   12358728 kB
# Buffers:          155924 kB
# Cached:          2085160 kB
# SwapCached:            0 kB
# Active:          1165936 kB
# Inactive:        1605840 kB
# Active(anon):     484896 kB
# Inactive(anon):      512 kB
# Active(file):     681040 kB
# Inactive(file):  1605328 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              3872 kB
# Writeback:             0 kB
# AnonPages:        530756 kB
# Mapped:           276152 kB
# Shmem:              1196 kB
# KReclaimable:     123808 kB
# Slab:             173644 kB
# SReclaimable:     123808 kB
# SUnreclaim:        49836 kB
# KernelStack:        6192 kB
# PageTables:         7616 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3723128 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       47084 kB
# VmallocChunk:          0 kB
# Percpu:             1424 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      162624 kB
# DirectMap2M:     6125568 kB
# DirectMap1G:     9437184 kB

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         167G   43G  125G  26% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  821M  59% /sbin/docker-init
# tmpfs           6.4G   28K  6.4G   1% /var/colab
# /dev/sda1       174G   46G  129G  27% /opt/bin/.nvidia
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           167G   49G  119G  29% /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Dec 20 03:17:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Train Interface

# %%
###############################################################################
#                           Warning Message Ignore                            #
###############################################################################
import os
import warnings
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.filterwarnings('ignore')
absl.logging.set_verbosity(absl.logging.ERROR)

###############################################################################
#                               Import modules                                #
###############################################################################
import config as cfg
from dataloader import load_data
from models import model
from tools_for_loss import sdr, si_snr, si_sdr, pmsqe_loss, pmsqe_log_mse_loss, stsa_mse, pmsqe_si_snr_loss
from tools_for_estimator import pesq, stoi
from tools_for_tensorboard import AudioTensorBoard

import time
from contextlib import redirect_stdout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

###############################################################################
#                                Load Datasets                                #
###############################################################################
X_train, y_train = load_data('train')
X_valid, y_valid = load_data('valid')

###############################################################################
#         Parameter Initialization and Setting for model training             #
###############################################################################
if cfg.loss == 'sdr':
    cfg.loss = sdr
elif cfg.loss == 'si_snr':
    cfg.loss = si_snr
elif cfg.loss == 'si_sdr':
    cfg.loss = si_sdr
elif cfg.loss == 'pmsqe_loss':
    cfg.loss = pmsqe_loss(cfg.batch)
elif cfg.loss == 'pmsqe_log_mse_loss':
    cfg.loss = pmsqe_log_mse_loss(cfg.batch)
elif cfg.loss == 'stsa_mse':
    cfg.loss = stsa_mse
elif cfg.loss == 'pmsqe_si_snr_loss':
    cfg.loss = pmsqe_si_snr_loss(cfg.batch)

if cfg.optimizer == 'adam':
    cfg.optimizer = Adam(clipnorm=1.)

for i in range(len(cfg.metrics)):
    if cfg.metrics[i] == 'pesq':
        cfg.metrics[i] = pesq
    elif cfg.metrics[i] == 'stoi':
        cfg.metrics[i] = stoi

if cfg.dir_add_time:
    t = time.strftime('%Y-%m-%d-%H-%M', time.localtime(time.time()))
    cfg.job_dir = cfg.job_dir + t
    cfg.logs_dir = cfg.logs_dir + t

atb = AudioTensorBoard(validation_data=(X_valid, y_valid),
                       log_dir=cfg.logs_dir,
                       batch_size=cfg.batch,
                       profile_batch=0)
cp = ModelCheckpoint(filepath=cfg.job_dir + cfg.job_file,
                     save_weights_only=True)

callbacks = []

if cfg.use_callbacks_metrics:
    callbacks.append(atb)
if cfg.model_checkpoint:
    callbacks.append(cp)

###############################################################################
#                                   Summary                                   #
###############################################################################

print()
model.summary()
print()
print('Models Save: ' + cfg.job_dir)
print('Logs Save: ' + cfg.logs_dir)
print()

if not os.path.exists(cfg.job_dir):
    os.makedirs(cfg.job_dir)
with open(cfg.job_dir + '/' + 'logs.txt', 'w') as f:
    with redirect_stdout(f):
        model.summary()

###############################################################################
#                                   Compile                                   #
###############################################################################
model.compile(loss=cfg.loss,
              optimizer=cfg.optimizer,
              metrics=cfg.metrics,
              run_eagerly=True)

###############################################################################
#                                    Train                                    #
###############################################################################
model.load_weights('models/2021-12-19-14-37/checkpoint-020.ckpt')

model.fit(X_train, y_train,
          epochs=cfg.max_epochs,
          initial_epoch=cfg.start_epochs,
          validation_data=(X_valid, y_valid),
          batch_size=cfg.batch,
          callbacks=callbacks,
          workers=-1,
          use_multiprocessing=True)

model.save_weights(cfg.job_dir + '/ckpt')
# Out:
# <Training dataset>
# Complete to load the data
# <Validation dataset>
# Complete to load the data
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 16000)]      0           []
#
#  tf.math.square_2 (TFOpLambda)  (None, 16000)        0           ['input_2[0][0]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (1, 16000)          0           ['tf.math.square_2[0][0]']
#  da)
#
#  tf.math.maximum_2 (TFOpLambda)  (1, 16000)          0           ['tf.math.reduce_sum_2[0][0]']
#
#  tf.math.sqrt_2 (TFOpLambda)    (1, 16000)           0           ['tf.math.maximum_2[0][0]']
#
#  tf.clip_by_value_2 (TFOpLambda  (1, 16000)          0           ['tf.math.sqrt_2[0][0]']
#  )
#
#  tf.math.multiply_6 (TFOpLambda  (1, 16000)          0           ['tf.clip_by_value_2[0][0]']
#  )
#
#  tf.math.multiply_7 (TFOpLambda  (1, 16000)          0           ['tf.math.sqrt_2[0][0]']
#  )
#
#  tf.__operators__.add_4 (TFOpLa  (1, 16000)          0           ['tf.math.multiply_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (1, 16000)          0           ['tf.math.sqrt_2[0][0]']
#  mbda)
#
#  tf.math.truediv_2 (TFOpLambda)  (1, 16000)          0           ['tf.__operators__.add_4[0][0]',
#                                                                   'tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 16000)       0           ['input_2[0][0]',
#  )                                                                'tf.math.truediv_2[0][0]']
#
#  stft_1 (STFT)                  (None, 163, 512, 2)  0           ['tf.math.multiply_8[0][0]']
#
#  tf.math.square_3 (TFOpLambda)  (None, 163, 512, 2)  0           ['stft_1[0][0]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (1, 163, 512, 2)    0           ['tf.math.square_3[0][0]']
#  da)
#
#  tf.math.maximum_3 (TFOpLambda)  (1, 163, 512, 2)    0           ['tf.math.reduce_sum_3[0][0]']
#
#  tf.math.sqrt_3 (TFOpLambda)    (1, 163, 512, 2)     0           ['tf.math.maximum_3[0][0]']
#
#  tf.clip_by_value_3 (TFOpLambda  (1, 163, 512, 2)    0           ['tf.math.sqrt_3[0][0]']
#  )
#
#  tf.math.multiply_9 (TFOpLambda  (1, 163, 512, 2)    0           ['tf.clip_by_value_3[0][0]']
#  )
#
#  tf.math.multiply_10 (TFOpLambd  (1, 163, 512, 2)    0           ['tf.math.sqrt_3[0][0]']
#  a)
#
#  tf.__operators__.add_6 (TFOpLa  (1, 163, 512, 2)    0           ['tf.math.multiply_9[0][0]',
#  mbda)                                                            'tf.math.multiply_10[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (1, 163, 512, 2)    0           ['tf.math.sqrt_3[0][0]']
#  mbda)
#
#  tf.math.truediv_3 (TFOpLambda)  (1, 163, 512, 2)    0           ['tf.__operators__.add_6[0][0]',
#                                                                   'tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 163, 512, 2)  0          ['stft_1[0][0]',
#  a)                                                               'tf.math.truediv_3[0][0]']
#
#  lambda_1 (Lambda)              [(None, 163, 512, 1  0           ['tf.math.multiply_11[0][0]']
#                                 ),
#                                  (None, 163, 512, 1
#                                 )]
#
#  conv2d_16 (Conv2D)             (None, 163, 512, 16  160         ['lambda_1[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 163, 512, 16  160         ['lambda_1[0][1]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 163, 512, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  batch_normalization_17 (BatchN  (None, 163, 512, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  p_re_lu_16 (PReLU)             (None, 163, 512, 16  1335296     ['batch_normalization_16[0][0]']
#                                 )
#
#  p_re_lu_17 (PReLU)             (None, 163, 512, 16  1335296     ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 163, 256, 16  2320        ['p_re_lu_16[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 163, 256, 16  2320        ['p_re_lu_17[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 163, 256, 16  64         ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  batch_normalization_19 (BatchN  (None, 163, 256, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  p_re_lu_18 (PReLU)             (None, 163, 256, 16  667648      ['batch_normalization_18[0][0]']
#                                 )
#
#  p_re_lu_19 (PReLU)             (None, 163, 256, 16  667648      ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 163, 128, 32  4640        ['p_re_lu_18[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 163, 128, 32  4640        ['p_re_lu_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 163, 128, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  batch_normalization_21 (BatchN  (None, 163, 128, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  p_re_lu_20 (PReLU)             (None, 163, 128, 32  667648      ['batch_normalization_20[0][0]']
#                                 )
#
#  p_re_lu_21 (PReLU)             (None, 163, 128, 32  667648      ['batch_normalization_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 163, 64, 32)  9248        ['p_re_lu_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 163, 64, 32)  9248        ['p_re_lu_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 163, 64, 32)  128        ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 163, 64, 32)  128        ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_22 (PReLU)             (None, 163, 64, 32)  333824      ['batch_normalization_22[0][0]']
#
#  p_re_lu_23 (PReLU)             (None, 163, 64, 32)  333824      ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 163, 32, 64)  18496       ['p_re_lu_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 163, 32, 64)  18496       ['p_re_lu_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 163, 32, 64)  256        ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 163, 32, 64)  256        ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_24 (PReLU)             (None, 163, 32, 64)  333824      ['batch_normalization_24[0][0]']
#
#  p_re_lu_25 (PReLU)             (None, 163, 32, 64)  333824      ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 163, 16, 64)  36928       ['p_re_lu_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 163, 16, 64)  36928       ['p_re_lu_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 163, 16, 64)  256        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 163, 16, 64)  256        ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_26 (PReLU)             (None, 163, 16, 64)  166912      ['batch_normalization_26[0][0]']
#
#  p_re_lu_27 (PReLU)             (None, 163, 16, 64)  166912      ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 163, 8, 128)  73856       ['p_re_lu_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 163, 8, 128)  73856       ['p_re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 163, 8, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 163, 8, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_28 (PReLU)             (None, 163, 8, 128)  166912      ['batch_normalization_28[0][0]']
#
#  p_re_lu_29 (PReLU)             (None, 163, 8, 128)  166912      ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 163, 4, 128)  147584      ['p_re_lu_28[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 163, 4, 128)  147584      ['p_re_lu_29[0][0]']
#
#  reshape_2 (Reshape)            (None, 163, 512)     0           ['conv2d_30[0][0]']
#
#  reshape_3 (Reshape)            (None, 163, 512)     0           ['conv2d_31[0][0]']
#
#  lstm_1 (LSTM)                  (None, 163, 512)     2099200     ['reshape_2[0][0]']
#
#  lstm_2 (LSTM)                  (None, 163, 512)     2099200     ['reshape_3[0][0]']
#
#  lstm_3 (LSTM)                  (None, 163, 512)     2099200     ['lstm_1[0][0]']
#
#  lstm_4 (LSTM)                  (None, 163, 512)     2099200     ['lstm_2[0][0]']
#
#  dense (Dense)                  (None, 163, 512)     262656      ['lstm_3[0][0]']
#
#  dense_1 (Dense)                (None, 163, 512)     262656      ['lstm_4[0][0]']
#
#  reshape_4 (Reshape)            (None, 163, 4, 128)  0           ['dense[0][0]']
#
#  reshape_5 (Reshape)            (None, 163, 4, 128)  0           ['dense_1[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 163, 4, 128)  512        ['reshape_4[0][0]']
#  ormalization)
#
#  cc_attention (CCAttention)     ((None, 163, 4, 128  132864      ['conv2d_30[0][0]',
#                                 ),                                'conv2d_31[0][0]']
#                                  (None, 163, 4, 128
#                                 ))
#
#  batch_normalization_33 (BatchN  (None, 163, 4, 128)  512        ['reshape_5[0][0]']
#  ormalization)
#
#  p_re_lu_32 (PReLU)             (None, 163, 4, 128)  83456       ['batch_normalization_32[0][0]']
#
#  cs_attention (CSAttention)     ((None, 163, 4, 128  394         ['cc_attention[0][0]',
#                                 ),                                'cc_attention[0][1]']
#                                  (None, 163, 4, 128
#                                 ))
#
#  p_re_lu_33 (PReLU)             (None, 163, 4, 128)  83456       ['batch_normalization_33[0][0]']
#
#  lambda_7 (Lambda)              (None, 163, 4, 256)  0           ['p_re_lu_32[0][0]',
#                                                                   'cs_attention[0][0]']
#
#  lambda_8 (Lambda)              (None, 163, 4, 256)  0           ['p_re_lu_33[0][0]',
#                                                                   'cs_attention[0][1]']
#
#  conv2d_transpose (Conv2DTransp  (None, 163, 8, 128)  295040     ['lambda_7[0][0]']
#  ose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 163, 8, 128)  295040     ['lambda_8[0][0]']
#  spose)
#
#  batch_normalization_34 (BatchN  (None, 163, 8, 128)  512        ['conv2d_transpose[0][0]']
#  ormalization)
#
#  cc_attention_1 (CCAttention)   ((None, 163, 8, 128  132864      ['conv2d_28[0][0]',
#                                 ),                                'conv2d_29[0][0]']
#                                  (None, 163, 8, 128
#                                 ))
#
#  batch_normalization_35 (BatchN  (None, 163, 8, 128)  512        ['conv2d_transpose_1[0][0]']
#  ormalization)
#
#  p_re_lu_34 (PReLU)             (None, 163, 8, 128)  166912      ['batch_normalization_34[0][0]']
#
#  cs_attention_1 (CSAttention)   ((None, 163, 8, 128  394         ['cc_attention_1[0][0]',
#                                 ),                                'cc_attention_1[0][1]']
#                                  (None, 163, 8, 128
#                                 ))
#
#  p_re_lu_35 (PReLU)             (None, 163, 8, 128)  166912      ['batch_normalization_35[0][0]']
#
#  lambda_14 (Lambda)             (None, 163, 8, 256)  0           ['p_re_lu_34[0][0]',
#                                                                   'cs_attention_1[0][0]']
#
#  lambda_15 (Lambda)             (None, 163, 8, 256)  0           ['p_re_lu_35[0][0]',
#                                                                   'cs_attention_1[0][1]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 163, 16, 64)  147520     ['lambda_14[0][0]']
#  spose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 163, 16, 64)  147520     ['lambda_15[0][0]']
#  spose)
#
#  batch_normalization_36 (BatchN  (None, 163, 16, 64)  256        ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  cc_attention_2 (CCAttention)   ((None, 163, 16, 64  33664       ['conv2d_26[0][0]',
#                                 ),                                'conv2d_27[0][0]']
#                                  (None, 163, 16, 64
#                                 ))
#
#  batch_normalization_37 (BatchN  (None, 163, 16, 64)  256        ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  p_re_lu_36 (PReLU)             (None, 163, 16, 64)  166912      ['batch_normalization_36[0][0]']
#
#  cs_attention_2 (CSAttention)   ((None, 163, 16, 64  394         ['cc_attention_2[0][0]',
#                                 ),                                'cc_attention_2[0][1]']
#                                  (None, 163, 16, 64
#                                 ))
#
#  p_re_lu_37 (PReLU)             (None, 163, 16, 64)  166912      ['batch_normalization_37[0][0]']
#
#  lambda_21 (Lambda)             (None, 163, 16, 128  0           ['p_re_lu_36[0][0]',
#                                 )                                 'cs_attention_2[0][0]']
#
#  lambda_22 (Lambda)             (None, 163, 16, 128  0           ['p_re_lu_37[0][0]',
#                                 )                                 'cs_attention_2[0][1]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 163, 32, 64)  73792      ['lambda_21[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 163, 32, 64)  73792      ['lambda_22[0][0]']
#  spose)
#
#  batch_normalization_38 (BatchN  (None, 163, 32, 64)  256        ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  cc_attention_3 (CCAttention)   ((None, 163, 32, 64  33664       ['conv2d_24[0][0]',
#                                 ),                                'conv2d_25[0][0]']
#                                  (None, 163, 32, 64
#                                 ))
#
#  batch_normalization_39 (BatchN  (None, 163, 32, 64)  256        ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  p_re_lu_38 (PReLU)             (None, 163, 32, 64)  333824      ['batch_normalization_38[0][0]']
#
#  cs_attention_3 (CSAttention)   ((None, 163, 32, 64  394         ['cc_attention_3[0][0]',
#                                 ),                                'cc_attention_3[0][1]']
#                                  (None, 163, 32, 64
#                                 ))
#
#  p_re_lu_39 (PReLU)             (None, 163, 32, 64)  333824      ['batch_normalization_39[0][0]']
#
#  lambda_28 (Lambda)             (None, 163, 32, 128  0           ['p_re_lu_38[0][0]',
#                                 )                                 'cs_attention_3[0][0]']
#
#  lambda_29 (Lambda)             (None, 163, 32, 128  0           ['p_re_lu_39[0][0]',
#                                 )                                 'cs_attention_3[0][1]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 163, 64, 32)  36896      ['lambda_28[0][0]']
#  spose)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 163, 64, 32)  36896      ['lambda_29[0][0]']
#  spose)
#
#  batch_normalization_40 (BatchN  (None, 163, 64, 32)  128        ['conv2d_transpose_6[0][0]']
#  ormalization)
#
#  cc_attention_4 (CCAttention)   ((None, 163, 64, 32  8640        ['conv2d_22[0][0]',
#                                 ),                                'conv2d_23[0][0]']
#                                  (None, 163, 64, 32
#                                 ))
#
#  batch_normalization_41 (BatchN  (None, 163, 64, 32)  128        ['conv2d_transpose_7[0][0]']
#  ormalization)
#
#  p_re_lu_40 (PReLU)             (None, 163, 64, 32)  333824      ['batch_normalization_40[0][0]']
#
#  cs_attention_4 (CSAttention)   ((None, 163, 64, 32  394         ['cc_attention_4[0][0]',
#                                 ),                                'cc_attention_4[0][1]']
#                                  (None, 163, 64, 32
#                                 ))
#
#  p_re_lu_41 (PReLU)             (None, 163, 64, 32)  333824      ['batch_normalization_41[0][0]']
#
#  lambda_35 (Lambda)             (None, 163, 64, 64)  0           ['p_re_lu_40[0][0]',
#                                                                   'cs_attention_4[0][0]']
#
#  lambda_36 (Lambda)             (None, 163, 64, 64)  0           ['p_re_lu_41[0][0]',
#                                                                   'cs_attention_4[0][1]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 163, 128, 32  18464      ['lambda_35[0][0]']
#  spose)                         )
#
#  conv2d_transpose_9 (Conv2DTran  (None, 163, 128, 32  18464      ['lambda_36[0][0]']
#  spose)                         )
#
#  batch_normalization_42 (BatchN  (None, 163, 128, 32  128        ['conv2d_transpose_8[0][0]']
#  ormalization)                  )
#
#  cc_attention_5 (CCAttention)   ((None, 163, 128, 3  8640        ['conv2d_20[0][0]',
#                                 2),                               'conv2d_21[0][0]']
#                                  (None, 163, 128, 3
#                                 2))
#
#  batch_normalization_43 (BatchN  (None, 163, 128, 32  128        ['conv2d_transpose_9[0][0]']
#  ormalization)                  )
#
#  p_re_lu_42 (PReLU)             (None, 163, 128, 32  667648      ['batch_normalization_42[0][0]']
#                                 )
#
#  cs_attention_5 (CSAttention)   ((None, 163, 128, 3  394         ['cc_attention_5[0][0]',
#                                 2),                               'cc_attention_5[0][1]']
#                                  (None, 163, 128, 3
#                                 2))
#
#  p_re_lu_43 (PReLU)             (None, 163, 128, 32  667648      ['batch_normalization_43[0][0]']
#                                 )
#
#  lambda_42 (Lambda)             (None, 163, 128, 64  0           ['p_re_lu_42[0][0]',
#                                 )                                 'cs_attention_5[0][0]']
#
#  lambda_43 (Lambda)             (None, 163, 128, 64  0           ['p_re_lu_43[0][0]',
#                                 )                                 'cs_attention_5[0][1]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 163, 256, 16  9232       ['lambda_42[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_11 (Conv2DTra  (None, 163, 256, 16  9232       ['lambda_43[0][0]']
#  nspose)                        )
#
#  batch_normalization_44 (BatchN  (None, 163, 256, 16  64         ['conv2d_transpose_10[0][0]']
#  ormalization)                  )
#
#  cc_attention_6 (CCAttention)   ((None, 163, 256, 1  2272        ['conv2d_18[0][0]',
#                                 6),                               'conv2d_19[0][0]']
#                                  (None, 163, 256, 1
#                                 6))
#
#  batch_normalization_45 (BatchN  (None, 163, 256, 16  64         ['conv2d_transpose_11[0][0]']
#  ormalization)                  )
#
#  p_re_lu_44 (PReLU)             (None, 163, 256, 16  667648      ['batch_normalization_44[0][0]']
#                                 )
#
#  cs_attention_6 (CSAttention)   ((None, 163, 256, 1  394         ['cc_attention_6[0][0]',
#                                 6),                               'cc_attention_6[0][1]']
#                                  (None, 163, 256, 1
#                                 6))
#
#  p_re_lu_45 (PReLU)             (None, 163, 256, 16  667648      ['batch_normalization_45[0][0]']
#                                 )
#
#  lambda_49 (Lambda)             (None, 163, 256, 32  0           ['p_re_lu_44[0][0]',
#                                 )                                 'cs_attention_6[0][0]']
#
#  lambda_50 (Lambda)             (None, 163, 256, 32  0           ['p_re_lu_45[0][0]',
#                                 )                                 'cs_attention_6[0][1]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 163, 512, 16  4624       ['lambda_49[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_13 (Conv2DTra  (None, 163, 512, 16  4624       ['lambda_50[0][0]']
#  nspose)                        )
#
#  batch_normalization_46 (BatchN  (None, 163, 512, 16  64         ['conv2d_transpose_12[0][0]']
#  ormalization)                  )
#
#  batch_normalization_47 (BatchN  (None, 163, 512, 16  64         ['conv2d_transpose_13[0][0]']
#  ormalization)                  )
#
#  p_re_lu_46 (PReLU)             (None, 163, 512, 16  1335296     ['batch_normalization_46[0][0]']
#                                 )
#
#  p_re_lu_47 (PReLU)             (None, 163, 512, 16  1335296     ['batch_normalization_47[0][0]']
#                                 )
#
#  lambda_51 (Lambda)             (None, 163, 512, 32  0           ['p_re_lu_46[0][0]',
#                                 )                                 'p_re_lu_16[0][0]']
#
#  lambda_52 (Lambda)             (None, 163, 512, 32  0           ['p_re_lu_47[0][0]',
#                                 )                                 'p_re_lu_17[0][0]']
#
#  conv2d_transpose_14 (Conv2DTra  (None, 163, 512, 1)  289        ['lambda_51[0][0]']
#  nspose)
#
#  conv2d_transpose_15 (Conv2DTra  (None, 163, 512, 1)  289        ['lambda_52[0][0]']
#  nspose)
#
#  batch_normalization_48 (BatchN  (None, 163, 512, 1)  4          ['conv2d_transpose_14[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 163, 512, 1)  4          ['conv2d_transpose_15[0][0]']
#  ormalization)
#
#  cs_attention_7 (CSAttention)   ((None, 163, 512, 1  394         ['lambda_1[0][0]',
#                                 ),                                'lambda_1[0][1]']
#                                  (None, 163, 512, 1
#                                 ))
#
#  p_re_lu_48 (PReLU)             (None, 163, 512, 1)  83456       ['batch_normalization_48[0][0]']
#
#  p_re_lu_49 (PReLU)             (None, 163, 512, 1)  83456       ['batch_normalization_49[0][0]']
#
#  lambda_57 (Lambda)             (None, 163, 512, 2)  0           ['cs_attention_7[0][0]',
#                                                                   'cs_attention_7[0][1]']
#
#  lambda_53 (Lambda)             (None, 163, 512, 2)  0           ['p_re_lu_48[0][0]',
#                                                                   'p_re_lu_49[0][0]']
#
#  multiply (Multiply)            (None, 163, 512, 2)  0           ['lambda_57[0][0]',
#                                                                   'lambda_53[0][0]']
#
#  istft (ISTFT)                  (None, 16000)        0           ['multiply[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 16000)        0           ['istft[0][0]']
#
#  tf.math.reduce_sum_4 (TFOpLamb  (1, 16000)          0           ['tf.math.square_4[0][0]']
#  da)
#
#  tf.math.maximum_4 (TFOpLambda)  (1, 16000)          0           ['tf.math.reduce_sum_4[0][0]']
#
#  tf.math.sqrt_4 (TFOpLambda)    (1, 16000)           0           ['tf.math.maximum_4[0][0]']
#
#  tf.clip_by_value_4 (TFOpLambda  (1, 16000)          0           ['tf.math.sqrt_4[0][0]']
#  )
#
#  tf.math.multiply_12 (TFOpLambd  (1, 16000)          0           ['tf.clip_by_value_4[0][0]']
#  a)
#
#  tf.math.multiply_13 (TFOpLambd  (1, 16000)          0           ['tf.math.sqrt_4[0][0]']
#  a)
#
#  tf.__operators__.add_8 (TFOpLa  (1, 16000)          0           ['tf.math.multiply_12[0][0]',
#  mbda)                                                            'tf.math.multiply_13[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (1, 16000)          0           ['tf.math.sqrt_4[0][0]']
#  mbda)
#
#  tf.math.truediv_4 (TFOpLambda)  (1, 16000)          0           ['tf.__operators__.add_8[0][0]',
#                                                                   'tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_14 (TFOpLambd  (None, 16000)       0           ['istft[0][0]',
#  a)                                                               'tf.math.truediv_4[0][0]']
#
# ==================================================================================================
# Total params: 26,064,794
# Trainable params: 26,061,462
# Non-trainable params: 3,332
# __________________________________________________________________________________________________
#
# Models Save: models/2021-12-20-03-56
# Logs Save: logs/2021-12-20-03-56
#
# Epoch 1/100
# 30/30 [==============================] - 30s 992ms/step - val_pesq: 2.1035 - val_stoi: 0.8627
# 1980/1980 [==============================] - 1879s 943ms/step - loss: -0.6612 - mae: 0.0660 - mse: 0.0137 - val_loss: -0.5432 - val_mae: 0.0676 - val_mse: 0.0140
# Epoch 2/100
# 30/30 [==============================] - 29s 968ms/step - val_pesq: 2.2846 - val_stoi: 0.8754
# 1980/1980 [==============================] - 1821s 920ms/step - loss: -0.7195 - mae: 0.0657 - mse: 0.0136 - val_loss: -0.6071 - val_mae: 0.0688 - val_mse: 0.0146
# Epoch 3/100
# 30/30 [==============================] - 29s 957ms/step - val_pesq: 2.3034 - val_stoi: 0.8689
# 1980/1980 [==============================] - 1788s 903ms/step - loss: -0.7508 - mae: 0.0654 - mse: 0.0135 - val_loss: -0.5921 - val_mae: 0.0674 - val_mse: 0.0140
# Epoch 4/100
# 30/30 [==============================] - 28s 941ms/step - val_pesq: 2.2230 - val_stoi: 0.8803
# 1980/1980 [==============================] - 1787s 903ms/step - loss: -0.7656 - mae: 0.0652 - mse: 0.0134 - val_loss: -0.6064 - val_mae: 0.0682 - val_mse: 0.0143
# Epoch 5/100
# 30/30 [==============================] - 28s 941ms/step - val_pesq: 2.2572 - val_stoi: 0.8753
# 1980/1980 [==============================] - 1784s 901ms/step - loss: -0.7894 - mae: 0.0650 - mse: 0.0133 - val_loss: -0.5931 - val_mae: 0.0688 - val_mse: 0.0146
# Epoch 6/100
# 30/30 [==============================] - 28s 947ms/step - val_pesq: 2.2589 - val_stoi: 0.8734
# 1980/1980 [==============================] - 1790s 904ms/step - loss: -0.8030 - mae: 0.0650 - mse: 0.0133 - val_loss: -0.6524 - val_mae: 0.0671 - val_mse: 0.0138
# Epoch 7/100
# 30/30 [==============================] - 29s 965ms/step - val_pesq: 2.3253 - val_stoi: 0.8763
# 1980/1980 [==============================] - 1805s 912ms/step - loss: -0.8189 - mae: 0.0650 - mse: 0.0133 - val_loss: -0.6528 - val_mae: 0.0678 - val_mse: 0.0141
# Epoch 8/100
# 30/30 [==============================] - 29s 956ms/step - val_pesq: 2.2977 - val_stoi: 0.8708
# 1980/1980 [==============================] - 1799s 909ms/step - loss: -0.8343 - mae: 0.0650 - mse: 0.0133 - val_loss: -0.6332 - val_mae: 0.0683 - val_mse: 0.0143
# Epoch 9/100
# 30/30 [==============================] - 28s 934ms/step - val_pesq: 2.3244 - val_stoi: 0.8803
# 1980/1980 [==============================] - 1795s 907ms/step - loss: -0.8370 - mae: 0.0650 - mse: 0.0133 - val_loss: -0.6514 - val_mae: 0.0676 - val_mse: 0.0140
# Epoch 10/100
# 30/30 [==============================] - 29s 960ms/step - val_pesq: 2.2408 - val_stoi: 0.8845
# 1980/1980 [==============================] - 1794s 906ms/step - loss: -0.8549 - mae: 0.0651 - mse: 0.0133 - val_loss: -0.6449 - val_mae: 0.0674 - val_mse: 0.0139
# Epoch 11/100
# 30/30 [==============================] - 29s 953ms/step - val_pesq: 2.3191 - val_stoi: 0.8800
# 1980/1980 [==============================] - 1801s 910ms/step - loss: -0.8616 - mae: 0.0648 - mse: 0.0132 - val_loss: -0.6010 - val_mae: 0.0664 - val_mse: 0.0135
# Epoch 12/100
# 30/30 [==============================] - 28s 934ms/step - val_pesq: 2.3169 - val_stoi: 0.8746
# 1980/1980 [==============================] - 1796s 907ms/step - loss: -0.8639 - mae: 0.0648 - mse: 0.0132 - val_loss: -0.6087 - val_mae: 0.0666 - val_mse: 0.0136
# Epoch 13/100
# 30/30 [==============================] - 28s 937ms/step - val_pesq: 2.4195 - val_stoi: 0.8882
# 1980/1980 [==============================] - 1781s 900ms/step - loss: -0.8577 - mae: 0.0646 - mse: 0.0132 - val_loss: -0.6541 - val_mae: 0.0670 - val_mse: 0.0138
# Epoch 14/100
# 30/30 [==============================] - 28s 942ms/step - val_pesq: 2.1380 - val_stoi: 0.8768
# 1980/1980 [==============================] - 1788s 903ms/step - loss: -0.8765 - mae: 0.0647 - mse: 0.0132 - val_loss: -0.6127 - val_mae: 0.0669 - val_mse: 0.0137
# Epoch 15/100
# 30/30 [==============================] - 29s 956ms/step - val_pesq: 2.2744 - val_stoi: 0.8755
# 1980/1980 [==============================] - 1788s 903ms/step - loss: -0.8823 - mae: 0.0646 - mse: 0.0131 - val_loss: -0.5991 - val_mae: 0.0662 - val_mse: 0.0135
# Epoch 16/100
# 30/30 [==============================] - 29s 968ms/step - val_pesq: 2.3355 - val_stoi: 0.8780
# 1980/1980 [==============================] - 1802s 910ms/step - loss: -0.8897 - mae: 0.0647 - mse: 0.0132 - val_loss: -0.6267 - val_mae: 0.0685 - val_mse: 0.0144
# Epoch 17/100
# 30/30 [==============================] - 29s 950ms/step - val_pesq: 2.3138 - val_stoi: 0.8751
# 1980/1980 [==============================] - 1812s 915ms/step - loss: -0.8985 - mae: 0.0647 - mse: 0.0132 - val_loss: -0.6535 - val_mae: 0.0675 - val_mse: 0.0140
# Epoch 18/100
# 30/30 [==============================] - 28s 944ms/step - val_pesq: 2.2259 - val_stoi: 0.8640
# 1980/1980 [==============================] - 1808s 913ms/step - loss: -0.9047 - mae: 0.0646 - mse: 0.0131 - val_loss: -0.6065 - val_mae: 0.0681 - val_mse: 0.0143
# Epoch 19/100
# 30/30 [==============================] - 28s 941ms/step - val_pesq: 2.3867 - val_stoi: 0.8830
# 1980/1980 [==============================] - 1807s 913ms/step - loss: -0.9075 - mae: 0.0647 - mse: 0.0132 - val_loss: -0.6626 - val_mae: 0.0668 - val_mse: 0.0137
# Epoch 20/100
# 30/30 [==============================] - 29s 950ms/step - val_pesq: 2.3521 - val_stoi: 0.8777
# 1980/1980 [==============================] - 1794s 906ms/step - loss: -0.9156 - mae: 0.0646 - mse: 0.0132 - val_loss: -0.5909 - val_mae: 0.0679 - val_mse: 0.0141
# Epoch 21/100
# 30/30 [==============================] - 28s 949ms/step - val_pesq: 2.3512 - val_stoi: 0.8719
# 1980/1980 [==============================] - 1808s 913ms/step - loss: -0.9164 - mae: 0.0647 - mse: 0.0132 - val_loss: -0.6183 - val_mae: 0.0677 - val_mse: 0.0140
# Epoch 22/100
# 30/30 [==============================] - 28s 939ms/step - val_pesq: 2.3201 - val_stoi: 0.8796
# 1980/1980 [==============================] - 1787s 902ms/step - loss: -0.9261 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6500 - val_mae: 0.0683 - val_mse: 0.0142
# Epoch 23/100
# 30/30 [==============================] - 28s 937ms/step - val_pesq: 2.2429 - val_stoi: 0.8768
# 1980/1980 [==============================] - 1765s 891ms/step - loss: -0.9291 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6372 - val_mae: 0.0671 - val_mse: 0.0138
# Epoch 24/100
# 30/30 [==============================] - 28s 941ms/step - val_pesq: 2.2869 - val_stoi: 0.8746
# 1980/1980 [==============================] - 1784s 901ms/step - loss: -0.9369 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6710 - val_mae: 0.0676 - val_mse: 0.0140
# Epoch 25/100
# 30/30 [==============================] - 29s 957ms/step - val_pesq: 2.1259 - val_stoi: 0.8666
# 1980/1980 [==============================] - 1778s 898ms/step - loss: -0.9365 - mae: 0.0646 - mse: 0.0131 - val_loss: -0.5944 - val_mae: 0.0681 - val_mse: 0.0143
# Epoch 26/100
# 30/30 [==============================] - 28s 926ms/step - val_pesq: 2.4265 - val_stoi: 0.8875
# 1980/1980 [==============================] - 1764s 891ms/step - loss: -0.9399 - mae: 0.0646 - mse: 0.0131 - val_loss: -0.6364 - val_mae: 0.0677 - val_mse: 0.0141
# Epoch 27/100
# 30/30 [==============================] - 28s 927ms/step - val_pesq: 2.3962 - val_stoi: 0.8807
# 1980/1980 [==============================] - 1777s 898ms/step - loss: -0.9514 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6519 - val_mae: 0.0676 - val_mse: 0.0140
# Epoch 28/100
# 30/30 [==============================] - 28s 932ms/step - val_pesq: 2.3019 - val_stoi: 0.8785
# 1980/1980 [==============================] - 1777s 898ms/step - loss: -0.9511 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6480 - val_mae: 0.0680 - val_mse: 0.0142
# Epoch 29/100
# 30/30 [==============================] - 28s 934ms/step - val_pesq: 2.4856 - val_stoi: 0.8832
# 1980/1980 [==============================] - 1765s 892ms/step - loss: -0.9585 - mae: 0.0646 - mse: 0.0131 - val_loss: -0.6479 - val_mae: 0.0674 - val_mse: 0.0140
# Epoch 30/100
# 30/30 [==============================] - 28s 937ms/step - val_pesq: 2.3187 - val_stoi: 0.8723
# 1980/1980 [==============================] - 1780s 899ms/step - loss: -0.9622 - mae: 0.0644 - mse: 0.0131 - val_loss: -0.6334 - val_mae: 0.0666 - val_mse: 0.0136
# Epoch 31/100
# 30/30 [==============================] - 28s 943ms/step - val_pesq: 2.3239 - val_stoi: 0.8803
# 1980/1980 [==============================] - 1786s 902ms/step - loss: -0.9687 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6466 - val_mae: 0.0684 - val_mse: 0.0144
# Epoch 32/100
# 30/30 [==============================] - 28s 934ms/step - val_pesq: 2.1959 - val_stoi: 0.8744
# 1980/1980 [==============================] - 1781s 899ms/step - loss: -0.9722 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6545 - val_mae: 0.0678 - val_mse: 0.0141
# Epoch 33/100
# 30/30 [==============================] - 28s 949ms/step - val_pesq: 2.3717 - val_stoi: 0.8827
# 1980/1980 [==============================] - 1791s 905ms/step - loss: -0.9773 - mae: 0.0644 - mse: 0.0131 - val_loss: -0.6740 - val_mae: 0.0676 - val_mse: 0.0140
# Epoch 34/100
# 30/30 [==============================] - 28s 949ms/step - val_pesq: 2.4806 - val_stoi: 0.8826
# 1980/1980 [==============================] - 1794s 906ms/step - loss: -0.9832 - mae: 0.0644 - mse: 0.0131 - val_loss: -0.5976 - val_mae: 0.0677 - val_mse: 0.0141
# Epoch 35/100
# 30/30 [==============================] - 29s 956ms/step - val_pesq: 2.2563 - val_stoi: 0.8807
# 1980/1980 [==============================] - 1795s 907ms/step - loss: -0.9777 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.5613 - val_mae: 0.0669 - val_mse: 0.0138
# Epoch 36/100
# 30/30 [==============================] - 29s 955ms/step - val_pesq: 2.3586 - val_stoi: 0.8830
# 1980/1980 [==============================] - 1786s 902ms/step - loss: -0.9787 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6403 - val_mae: 0.0674 - val_mse: 0.0140
# Epoch 37/100
# 30/30 [==============================] - 28s 946ms/step - val_pesq: 2.3114 - val_stoi: 0.8790
# 1980/1980 [==============================] - 1804s 911ms/step - loss: -0.9842 - mae: 0.0644 - mse: 0.0131 - val_loss: -0.6424 - val_mae: 0.0666 - val_mse: 0.0136
# Epoch 38/100
# 30/30 [==============================] - 29s 951ms/step - val_pesq: 2.2523 - val_stoi: 0.8736
# 1980/1980 [==============================] - 1794s 906ms/step - loss: -0.9904 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6625 - val_mae: 0.0675 - val_mse: 0.0140
# Epoch 39/100
# 30/30 [==============================] - 28s 949ms/step - val_pesq: 2.3123 - val_stoi: 0.8795
# 1980/1980 [==============================] - 1804s 911ms/step - loss: -0.9931 - mae: 0.0646 - mse: 0.0132 - val_loss: -0.6669 - val_mae: 0.0671 - val_mse: 0.0138
# Epoch 40/100
# 30/30 [==============================] - 29s 950ms/step - val_pesq: 2.1655 - val_stoi: 0.8686
# 1980/1980 [==============================] - 1808s 913ms/step - loss: -0.9934 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6086 - val_mae: 0.0674 - val_mse: 0.0139
# Epoch 41/100
# 30/30 [==============================] - 29s 951ms/step - val_pesq: 2.2424 - val_stoi: 0.8830
# 1980/1980 [==============================] - 1805s 911ms/step - loss: -0.9972 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6387 - val_mae: 0.0660 - val_mse: 0.0133
# Epoch 42/100
# 30/30 [==============================] - 29s 954ms/step - val_pesq: 2.3843 - val_stoi: 0.8843
# 1980/1980 [==============================] - 1803s 911ms/step - loss: -1.0071 - mae: 0.0646 - mse: 0.0132 - val_loss: -0.6781 - val_mae: 0.0668 - val_mse: 0.0137
# Epoch 43/100
# 30/30 [==============================] - 28s 945ms/step - val_pesq: 2.3285 - val_stoi: 0.8811
# 1980/1980 [==============================] - 1807s 913ms/step - loss: -1.0067 - mae: 0.0646 - mse: 0.0132 - val_loss: -0.6387 - val_mae: 0.0660 - val_mse: 0.0134
# Epoch 44/100
# 30/30 [==============================] - 29s 951ms/step - val_pesq: 2.3498 - val_stoi: 0.8900
# 1980/1980 [==============================] - 1802s 910ms/step - loss: -1.0139 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6414 - val_mae: 0.0665 - val_mse: 0.0136
# Epoch 45/100
# 30/30 [==============================] - 29s 956ms/step - val_pesq: 2.2139 - val_stoi: 0.8763
# 1980/1980 [==============================] - 1797s 908ms/step - loss: -1.0157 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6430 - val_mae: 0.0687 - val_mse: 0.0145
# Epoch 46/100
# 30/30 [==============================] - 29s 960ms/step - val_pesq: 2.3463 - val_stoi: 0.8753
# 1980/1980 [==============================] - 1804s 911ms/step - loss: -1.0096 - mae: 0.0645 - mse: 0.0131 - val_loss: -0.6499 - val_mae: 0.0661 - val_mse: 0.0134
# Epoch 47/100
#   37/1980 [..............................] - ETA: 29:43 - loss: -1.0722 - mae: 0.0664 - mse: 0.0139
